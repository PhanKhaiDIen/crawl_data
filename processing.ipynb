# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    480 non-null    int64
#  1   category      480 non-null    object
#  2   product_name  480 non-null    object
#  3   price         480 non-null    int64
#  4   image         480 non-null    object
#  5   image_url     480 non-null    object
#  6   source        480 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 26.4+ KB

# %%
df.head(10)
# Out:
#    product_id     category                                       product_name  \
# 0   278237932  Smart Phone      Điện thoại Xiaomi Redmi 14C - Hàng chính hãng
# 1   278098703  Smart Phone  Điện thoại POCO C75 (8GB/256GB) - Hàng Chính H...
# 2   278000720  Smart Phone  Điện thoại HONOR X5b Plus 4GB/128GB - Hàng chí...
# 3   277930407  Smart Phone  Điện thoại Tecno Spark GO 1 (3GB/64GB) - Hàng ...
# 4   277811118  Smart Phone  Điện Thoại Xiaomi Redmi Note 14 5G 8GB/256GB -...
# 5   277737595  Smart Phone  Điện Thoại Samsung A06 5G 4GB/128GB - Hàng Chí...
# 6   277574339  Smart Phone  Củ Sạc Samsung Không Kèm Cáp 25W - Hàng Chính ...
# 7   277512620  Smart Phone  Điện Thoại Samsung A36 5G 8GB/128GB - Hàng Chí...
# 8   277512611  Smart Phone  Điện Thoại Samsung A56 5G 8GB/128GB - Hàng Chí...
# 9   277360579  Smart Phone  Điện Thoại Xiaomi Redmi 13 8GB/128GB - Hàng Ch...
#
#      price                      image  \
# 0  2210000  Smart_Phone/278237932.jpg
# ...
