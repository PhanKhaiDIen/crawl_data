# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("data.xlsx")

# %%
df.head(5)
# Out:
#    product_id                                       product_name     category  \
# 0   278237932      Điện thoại Xiaomi Redmi 14C - Hàng chính hãng  Smart Phone
# 1   278098703  Điện thoại POCO C75 (8GB/256GB) - Hàng Chính H...  Smart Phone
# 2   278000720  Điện thoại HONOR X5b Plus 4GB/128GB - Hàng chí...  Smart Phone
# 3   277930460  Điện thoại Vivo Y19s (4GB/128GB) - Hàng Chính ...  Smart Phone
# 4   277930407  Điện thoại Tecno Spark GO 1 (3GB/64GB) - Hàng ...  Smart Phone
#
#      price                                           image  \
# 0  2410000   Smart_Phone/278237932_6694396177086439719.jpg
# 1  2790000  Smart_Phone/278098703_-1289924426043266980.png
# 2  1950000   Smart_Phone/278000720_6277121141886529958.jpg
# 3  3090000   Smart_Phone/277930460_4106675735388814067.jpg
# 4  1690000   Smart_Phone/277930407_5889783681040735563.png
#
#                                            image_url  \
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                                               source platform
# 0  https://tiki.vn/dien-thoai-xiaomi-redmi-14c-ha...     Tiki
# 1  https://tiki.vn/dien-thoai-poco-c75-8gb-256gb-...     Tiki
# 2  https://tiki.vn/dien-thoai-honor-x5b-plus-4gb-...     Tiki
# 3  https://tiki.vn/dien-thoai-vivo-y19s-4gb-128gb...     Tiki
# 4  https://tiki.vn/dien-thoai-tecno-spark-go-1-3g...     Tiki

# %%
df.tail(5)
# Out:
#               product_id                                       product_name  \
# 955  4078163125723441185  Đồng Zhimi 3 đèn đỏ, thể thao nút bấm, đồng hồ...
# 956  6238131453512137799  Đồng điện tử cho nam nữ, sinh trung học và cao...
# 957  5433909120756158526  [HCM]Đồng Hồ Thông Minh Q12 Dành Cho Trẻ Em 1....
# 958   -99284279047649469  Đồng hồ trẻ em bé trai bé gái Chống Nước 50M C...
# 959 -4494356357612022940  Tập Thể Dục M3 Màn Hình Màu Thông Minh Vòng Đe...
#
#         category   price image  \
# 955  Smart Watch  166823   NaN
# 956  Smart Watch  173924   NaN
# 957  Smart Watch  500000   NaN
# 958  Smart Watch   27600   NaN
# 959  Smart Watch  238874   NaN
#
#                                              image_url  \
# 955  ......
# 956  ......
# 957  ......
# 958  ......
# 959  ......
#
#                                                 source platform
# 955  https://www.lazada.vn/products/pdp-i3150719252...   Lazada
# 956  https://www.lazada.vn/products/pdp-i3150615881...   Lazada
# 957  https://www.lazada.vn/products/pdp-i1417976244...   Lazada
# 958  https://www.lazada.vn/products/pdp-i2504784794...   Lazada
# 959  https://www.lazada.vn/products/pdp-i2515610844...   Lazada

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    960 non-null    int64
#  1   product_name  960 non-null    object
#  2   category      960 non-null    object
#  3   price         960 non-null    int64
#  4   image         768 non-null    object
#  5   image_url     960 non-null    object
#  6   source        960 non-null    object
#  7   platform      960 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 60.1+ KB

# %%
df = df[df['image'].notna()]
df = df[df['image'].str.strip() != '']

# %%
df = df[df['product_id'] >= 0]

# %%
print(f"Số dòng còn lại: {len(df)}")
# Out:
# Số dòng còn lại: 624

# %%
df = df.sort_values(by='category').reset_index(drop=True)

# %%
category_prefix = {
    "Smart Phone": "SM",
    "Smart Watch": "SW",
    "Headphones": "H",
    "Speaker": "SP",
    "Power Bank": "P",
    "Mouse": "M"
}

# %%
df = df.copy()

# %%
df['serial_code'] = (df.groupby('category').cumcount() + 1).astype(str).str.zfill(2)
df['serial_code'] = df['category'].map(category_prefix) + df['serial_code']

# %%
cols = ['serial_code'] + [col for col in df.columns if col != 'serial_code']
df = df[cols]

# %%
df.head(5)
# Out:
#   serial_code  product_id                                       product_name  \
# 0         H01   276515204  Tai nghe bluetooth nhét tai RiBi X55 - Siêu mỏ...
# 1         H02   142127420  Tai nghe game không dây Bluetooth và Lighspeed...
# 2         H03   135284107  Headphone Tai Nghe Chụp Tai bluetooth Rockspac...
# 3         H04   118191706  Tai nghe bluetooth F9 Pro thương hiệu PAGINI p...
# 4         H05   113569143  Tai nghe bluetooth chụp tai Remax RB-620HB kiể...
#
#      category    price                                          image  \
# 0  Headphones    99000  Headphones/276515204_-5636611889457927481.jpg
# 1  Headphones  1509000   Headphones/142127420_8346210696221133712.png
# 2  Headphones   363168   Headphones/135284107_5436393584853721349.png
# 3  Headphones    79000   Headphones/118191706_6794962277218334137.JPG
# 4  Headphones   631750   Headphones/113569143_7467594109960574006.jpg
#
#                                            image_url  \
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                                               source platform
# 0  https://tiki.vn/tai-nghe-bluetooth-nhet-tai-ri...     Tiki
# 1  https://tiki.vn/tai-nghe-game-khong-day-blueto...     Tiki
# 2  https://tiki.vn/headphone-tai-nghe-chup-tai-bl...     Tiki
# 3  https://tiki.vn/tai-nghe-bluetooth-f9-pro-thuo...     Tiki
# 4  https://tiki.vn/tai-nghe-khong-day-chup-lai-re...     Tiki

# %%
df.to_excel("data_cleaned.xlsx", index=False)
