# %%
import os
import requests
import pandas as pd

# %%
CATEGORY_ID = 8039
CATEGORY_NAME = "Đồng hồ thông minh"
NUM_PAGES = 2
SAVE_DIR = "images/watch"
os.makedirs(SAVE_DIR, exist_ok=True)

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

records = []

def download_image(url, save_path):
    try:
        response = requests.get(url, headers=HEADERS)
        if response.status_code == 200:
            with open(save_path, "wb") as f:
                f.write(response.content)
    except Exception as e:
        print(f"Lỗi khi tải ảnh: {e}")

# %%
for page in range(1, NUM_PAGES + 1):
    api_url = f"https://tiki.vn/api/personalish/v1/blocks/listings?limit=40&category={CATEGORY_ID}&page={page}&sort_by=popularity"

    try:
        response = requests.get(api_url, headers=HEADERS)
        if response.status_code != 200:
            print(f"⚠️ Lỗi HTTP {response.status_code} tại trang {page}")
            continue

        data = response.json()
    except Exception as e:
        print("Không thể phân tích JSON:", e)
        print("Phản hồi:", response.text[:300])
        continue

    for item in data.get("data", []):
        product_id = item.get("id")
        name = item.get("name", "no_name")
        price = item.get("price", 0)
        image_url = item.get("thumbnail_url")

        if not image_url or not product_id:
            continue

        filename = f"{product_id}.jpg"
        full_path = os.path.join(SAVE_DIR, filename)
        download_image(image_url, full_path)

        records.append({
            "product_id": product_id,
            "category": CATEGORY_NAME,
            "product_name": name,
            "price": price,
            "image": filename,
            "source": image_url
        })

        print(f"Đã tải: {name}")
# Out:
# Đã tải: Dây Cáp Sạc Từ Tính cho Đồng Hồ Xiaomi Mi Band 5/ Mi Band 6/ Mi Band 7/ Mi band 8/ Mi band 9/ Mi band 10- Hàng chính hãng - Miband 5/6/7
# Đã tải: Dây đeo cho vòng đeo tay thông minh Xiaomi MiBand 8/ Miband 9/ Mi band 10 ngàm thép_ Hàng Chính Hãng
# Đã tải: Cáp sạc thay thế cho các dòng đồng hồ Garmin Fenix 7, Fenix 6, Fenix 5, Forerunner 955, 945, 935, 245, 265, 255, 45, 645, Instinct, Viviactive 3, Venu/ Garmin Epix Gen 2- Hàng Nhập Khẩu
# Đã tải: Vòng Đeo Tay Thông Minh Xiaomi Smart Band 9 Active – Hàng Chính Hãng
# Đã tải: Dock Sạc Cho Huawei Watch GT 2 Pro / GT Runner / GT3/3Pro / GT4/4Pro / Huawei Watch GT5 / Huawei Watch GT 5 Pro - Hàng Chính Hãng
# Đã tải: Đồng Hồ Thông Minh Xiaomi Redmi Watch 5 ACTIVE – Hàng Chính Hãng
# Đã tải: Cáp Sạc Đế Sạc cho Samsung Galaxy Watch 3/4/4Classic/5/5Pro/6/6Classic/7/Ultra & Galaxy Watch Active 1/2- Hàng Chính Hãng
# Đã tải: Apple Watch Series 10 GPS (Viền nhôm, dây cao su)
# Đã tải: Apple Watch SE 2024 GPS (Viền nhôm, dây cao su)
# Đã tải: Dây Đeo Inox Khóa Nam Châm dành cho Đồng Hồ Thông Minh AMA TK, S16 và các Các mẫu Đồng hồ có kích thước dây 42/44/45/49mm Hàng chính hãng
# Đã tải: Miếng dán kính cường lực cho đồng hồ Samsung Galaxy Watch Ultra/ Galaxy Watch 7 44/40mm Full HD Clear 2.5D_ Hàng chính hãng
# Đã tải: Dây Đeo Đồng Hồ KAi.N Sport Pro cho Huawei Watch Fit 3/Fit 4/ Fit 4 Pro_Hàng chính hãng
# Đã tải: Dây Đồng Hồ Dành Cho Huawei Watch Fit 3/ Fit 4/ Fit 4 Pro, Kai.N Sport Pro_ Hàng chính hãng
# Đã tải: Dây đeo Silicone thay thế cho Huawei Watch Fit 3 / Fit 4 / Fit 4 Pro - Hàng Chính Hãng
# Đã tải: Đồng Hồ Thông Minh Trẻ Em MAI DUY Y85S, Lắp Sim Nghe Gọi - Định Vị Cảnh Báo Nguy Hiểm, Chống Nước  -Hàng Nhập Khẩu
# Đã tải: Cáp sạc cho Đồng Hồ Samsung Galaxy Fit 3 R390 cổng type C, Kai.N Charge_ Hàng chính hãng
# Đã tải: Dây cáp sạc cho Đồng Hồ Samsung Galaxy Fit 3 R390 cổng USB C_ Hàng chính hãng
# Đã tải: Dây Đeo Thép Thay Thế Dành Cho Samsung Galaxy Fit 3, Kai.N Milanese Pro_ Hàng Chính Hãng
# Đã tải: Dây Silicon Khóa Thể Thao cho Apple Watch Series 1/2/3/4/5/6/7/8/9/SE1,2 & Apple Watch Ultra 1/2 Size 38/40/41/42/44/45/49mm - Hàng Chính Hãng
# Đã tải: Đồng hồ Samsung Galaxy Fit 3 - Hàng Chính Hãng
# Đã tải: Ốp Case Bảo Vệ Dành Cho Apple Watch Dux Ducis Tamo Series Hard PC + Soft Silicone _ Hàng Chính Hãng
# Đã tải: Dây đeo Nylon Loop cho Xiaomi Mi Band 8 / Xiaomi Mi Band 9 / Xiaomi Mi Band 10 - Hàng Nhập Khẩu
# Đã tải: Đồng hồ Thông minh Trẻ em Học sinh Tiểu học THCS THPT Chống nước Lắp sim Định vị Kép Smart Watch AMA HW13 Hàng nhập khẩu
# Đã tải: Dây Đeo Thay Thế Dành Cho Vòng Đeo Tay Thông Minh Xiaomi MiBand 8/ Miband 9/ Mi band 10 Ngàm Thép Chắc Chắn_ Hàng Chính Hãng
# Đã tải: Cáp sạc thay thế cho các dòng đồng hồ Garmin Fenix 7, Fenix 6, Fenix 5, Forerunner 955, 945, 935, 245, 265, 255, 45, 645, Instinct, Viviactive 3, Venu/ Garmin Epix Gen 2- Hàng Chính Hãng
# Đã tải: Dây Đồng Hồ Dành Cho Apple Watch KAi.N Sport Magnetic- Hàng Chính Hãng
# Đã tải: Dock Sạc Nhanh Dành Cho Samsung Galaxy Watch 6/ 7/ Galaxy Watch Ultra/ Galaxy Watch 5/ Galaxy Watch 5 Pro/ Galaxy Watch 4/ Galaxy Watch 3 Cổng Type C_ Hàng chính hãng
# Đã tải: Dây Đeo Da Dành Cho Apple Watch Ultra / Apple Watch Series 1-8/SE/SE 2022, Kai.N_Genuine Leather - Hàng Chính Hãng
# Đã tải: Shinecon G07E - Kính Thực Tế Ảo VR Shinecon 2018 version 7 G07E - Hàng Chính Hãng - VR SHINECON G07E 9th Generation Virtual Reality 3D Video Glasses Game Virtual Reality Glasses VR Headset Helmet for Android IOS
# Đã tải: Đồng hồ Thông minh Mini có Rung Gắn sim Định vị GPS, Wifi Đo huyết áp Nhịp tim nhắc nhở Vận động gọi Video call AMA Watch FA91S - Hàng nhập khẩu
# Đã tải: Dây Silicon dành cho đồng hồ Apple nhiều màu- Hàng chính hãng
# Đã tải: Dock Sạc Dành Cho Huawei Watch GT3 / Huawei Watch GT Runner / Huawei Watch GT3 Pro/ Huawei Watch 4 / Huawei Watch 4 Pro / Huawei Watch GT 4/ GT5/ GT5 Pro - Hàng Chính Hãng
# Đã tải: Dây Đeo Thay Thế Dành Cho Vòng Đeo Tay Thông Minh Xiaomi MiBand 7 Dẻo TPU- Hàng chính hãng
# Đã tải: Dây Đeo Thay Thế Viền Dành Cho Vòng Đeo Tay Thông Minh Xiaomi Mi Band 5/ Miband 6 - Hàng chính hãng
# Đã tải: Dây Đeo Sport Loop Kai Dành Cho Apple Watch- Hàng Chính Hãng
# Đã tải: Đồng hồ Thông minh Trẻ em AMA Watch Q15 lắp SIM nghe gọi 2 chiều 3 màu Xanh Hồng Đen Hàng chinh hãng
# Đã tải:  Đồng Hồ Thông Minh Trẻ em AMA Q12S Model mới nhất ra mắt tháng 12/2021 - Hàng nhập khẩu
# Đã tải: Đồng Hồ Thông Minh cho Trẻ em 6 tuổi, 7 tuổi, 8 tuổi, 9 tuổi, 10 tuổi, 11 tuổi Lắp Sim Độc lập nghe gọi 2 chiều AMA Watch Y92 Chống nước Định vị Wifi độ chính xác cao Hàng nhập khẩu
# Đã tải: Dây sạc Cáp sạc Nam châm Đồng hồ Thông minh Q12, Q16, Q19, Q100, TD26, A28, DS60, DS66, Y95, D06, DF39 Hàng nhập khẩu
# Đã tải: Kính Thực Tế Ảo Xem Phim 3D VR Shinecon Cao Cấp AZONE - Hàng Nhập Khẩu
# Đã tải: Dây đeo Nylon Loop cho Huawei Watch Fit 3 / Huawei Watch Fit 4 / Huawei Watch Fit 4 Pro - Hàng Chính Hãng
# Đã tải: Dock sạc nhanh khung nhôm Hoco CW59 dành cho Apple watch/ Samsung Galaxy Watch cổng type C, Dây Bọc Dù_ Hàng Chính Hãng
# Đã tải: Dây đeo Silicone cho Redmi Watch 5 / Redmi Watch 4 / Xiaomi Mi Band 8 Pro / Xiaomi Mi Band 9 Pro  - Hàng Chính Hãng
# Đã tải: Dây Thép cho Redmi Watch 5 / Redmi Watch 4 / Xiaomi Mi Band 8 Pro / Xiaomi Mi Band 9 Pro  - Hàng Chính Hãng
# Đã tải: Dây đeo Silicone thay thế cho Xiaomi Mi Band 9 Pro / Xiaomi Mi Band 8 Pro / Redmi Watch 5 / Redmi Watch 4  - Hàng Chính Hãng
# Đã tải: Giá Đỡ dành cho Dock Sạc Apple Watch Kai.N Game PS Silicone Stand Hình Máy Game Chống Đứt Gãy Dây_ Hàng Chính Hãng
# Đã tải: Miếng Dán Cường Lực GOR cho Huawei Watch GT 5 41/46mm & Huawei Watch GT 5 Pro 42/46mm - Hàng Chính Hãng
# Đã tải: Dock Sạc Type-C Thay Thế dành cho Đồng Hồ Garmin Fenix / Forerunner / Instinct / Vivoactive / Vivomove / Venu / Approach / Epix - Hàng Chính Hãng
# Đã tải: Dây Cao Su Thay Thế cho Samsung Galaxy Fit 2 (SM-R220)- Hàng Nhập Khẩu
# Đã tải: Vòng Đeo Tay Thông Minh Xiaomi Mi Band 10 - Bản Quốc Tế - Hàng Chính Hãng
# Đã tải: Dây đeo tích hợp case vỏ bảo vệ cho Xiaomi Mi Band 8 / Xiaomi Mi Band 9 / Xiaomi Mi Band 10 - Hàng Chính Hãng
# Đã tải: Dây đeo Silicone thay thế cho Xiaomi Mi Band 8 / Xiaomi Mi Band 9 / Xiaomi Mi Band 10 - Hàng Chính Hãng
# Đã tải: Dây Đeo Thép Thay Thế Dành Cho Huawei Watch Fit 3/ Fit 4/ Fit 4 Pro, Kai.N Milanese Pro Huawei Fit 3_ Hàng chính hãng
# Đã tải: Dây Đeo Thay Thế  Dành Cho Vòng Đeo Tay Thông Minh Samsung Galaxy Fit 3_ Hàng chính hãng
# Đã tải: Dây đeo Vải Dệt Dux Ducis Mixture Pro Series Dành Cho Apple Watch Ultra/ Apple Watch All Series_ Hàng chính hãng
# Đã tải: Dây Nylon Alpine Loop cho Apple Watch Series 1/2/3/4/5/6/7/8/9/SE1,2 & Apple Watch Ultra 1/2 Size 38/40/41/42/44/45/49mm - Hàng Nhập Khẩu
# Đã tải: Đồng hồ Thông minh Lắp Sim Định vị GPS Google kết nối Wifi 4G Blueltooth xem được Video Youtube TikTok tải App FB Messenger Skype WhatsApp Viber Wechat Kakao Line Tele chơi Game AMA Smart watch TK Android 8.1 cho Trẻ em Người lớn Hàng nhập khẩu
# Đã tải: Miếng Dán Mặt Đồng Hồ TPU Hydrogel Film Chống Trầy cho Apple Watch 4/5/6/7/8/9/ SE Ultra_ Hàng chính hãng
# Đã tải: Cáp sạc nhanh thay thế cho các dòng đồng hồ Garmin cổng Type C- Hàng Chính Hãng
# Đã tải: Dây Đeo Thay Thế Dành Cho Galaxy Watch 5/4/3, Huawei Watch GT/GT2/GT3/Pro, Amazfit GT2/3/4,Garmin Size 20/22mm, Kai.N Sport Band - Hàng Chính Hãng
# Đã tải: Dây Đeo Silicone Đồng hồ samsung watch 4/ watch 5- Hàng chính hãng
# Đã tải: Đồng Hồ Thông Minh Trẻ Em AMA Watch Q12B Hàng nhập khẩu
# Đã tải: Dây Đeo Dành Cho Đồng Hồ Thông Minh Garmin Quickfit, Kai.N Garmin Sport Armor Band - Hàng Chính Hãng
# Đã tải: Ốp Case Bảo Vệ Dành Cho Apple Watch Kai.N Guard Case_ Hàng Chính Hãng
# Đã tải: Đồng hồ Thông minh gắn Sim nghe gọi Chống nước IP67 Gọi Video call Định vị GPS, WIfi dàn cho Trẻ em học sinh cấp 1 2 5 6 7 8 9 10 11 12 tuổi AMA Watch D32 Hàng nhập khẩu
# Đã tải: Bộ 2 miếng dán Gor 3D cho Apple Watch Series 4/ 5/ 6/ 7/ 8/ 9/ SE Size40/ 41/ 44/ 45 mm ( hộp 2 miếng) _Hàng chính hãng
# Đã tải: Dán Film cường lực Full 3D dành cho Apple Watch Series 10 42mm / 46mm hiệu WIWU iVista Chống va đập, vát cạnh 2.5D, hạn chế vân tay - hàng nhập khẩu
# Đã tải: Kính Cường Lực Đồng hồ Thông minh Q12, Q15, Q12B, D06S, LT31, DH11, G2, A28, DS60, M80, Q16S, K10 Kích thước 30mm x 35mm Hàng nhập khẩu
# Đã tải: Đồng Hồ Định Vị Trẻ Em Wonlex KT18 - Hàng Chính Hãng
# Đã tải: Ốp Case Kèm Dây Đeo Kiểu Gshock Kai dành cho Đồng Hồ Apple Watch- Hàng Chính Hãng
# Đã tải: Đồng hồ thông minh Samsung Galaxy Watch5 40mm SM-R900N - Hàng chính hãng
# Đã tải: Cáp Sạc Thay Thế Nillkin dành cho Đồng Hồ Garmin Fenix / Forerunner  / Instinct / Vivoactive / Vivomove / Venu / Approach / Epix - Hàng Chính Hãng
# Đã tải: Cáp Sạc Cho Đồng Hồ Huami Amazfit GTS3/ GTR3/ GTR3 Pro/ T-Rex 2/ GTR 4/ GTS 4- Hàng chính hãng
# Đã tải: Đồng hồ Thông minh Chống nước IP67 Dành cho Trẻ em nhuẩn AMA Watch Q16S Hàng chính hãng
# Đã tải: Dây Cao Su Sport Color dành cho Samsung Galaxy Fit 2 (SM-R220)- Hàng chính hãng
# Đã tải: Dây Cao Su Thay Thế cho Samsung Galaxy Fit 2 (SM-R220)- Hàng chính hãng
# Đã tải: Dán màn hình 3D GOR cho Apple Watch Series 9/ Series 8/ Series 7 Size 41mm / 45mm (Hộp 2 Miếng) - Hàng Chính Hãng
# Đã tải: Đồng Hồ Thông Minh AMA Watch Nam Nữ chống nước | Gọi điện thoại Xem tin nhắn Theo dõi Sức khỏe vận động Thiết kế nhỏ gọn Thời trang Hàng nhập khẩu
# Đã tải: Đồng Hồ Thông Minh AMA Watch S2 | Nam Nữ | Chống nước | Kết nối Bluetooth gọi Điện thoại Theo dõi Sức khỏe Vận động Màn hình cong tràn viền Hàng nhập khẩu
# Đã tải: Đồng Hồ Thông Minh Nữ AMA Watch S27 Thời trang Kết nối Bluetooth Theo dõi Sức khỏe Vận động Màn hình tròn Hàng chính hãng

# %%
df = pd.DataFrame(records)
df.to_excel("data.xlsx", index=False)
print(f"\n📦 Đã lưu {len(records)} sản phẩm vào file 'smartwatch_data.xlsx'")
# Out:
# 📦 Đã lưu 80 sản phẩm vào file 'smartwatch_data.xlsx'
