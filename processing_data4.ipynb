# %% [markdown]
# Configuration

# %%
# Đường dẫn thư mục ảnh
IMAGE_FOLDER = "images_png"

# Ngưỡng similarity
SIMILARITY_THRESHOLD = 0.9

# File cache
CACHE_FILE = "feature_cache.pkl"

# File output
OUTPUT_FILE = "duplicates.txt"

# %%
import os
import numpy as np
import pandas as pd
import cv2 
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image
from tqdm import tqdm
import pickle
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Feature Extractor (Trích xuất đặc trưng)

# %%
class FeatureExtractor:
    def __init__(self):
        self.model = ResNet50(weights="imagenet", include_top=False, pooling="avg")
    
    def extract_features(self, img_path, target_size=(224, 224)):
        """Trích xuất vector đặc trưng từ một ảnh"""
        try:
            img = image.load_img(img_path, target_size=target_size)
            x = image.img_to_array(img)
            x = np.expand_dims(x, axis=0)
            x = preprocess_input(x)
            features = self.model.predict(x, verbose=0)
            return features[0]
        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_path}: {str(e)}")
            return None
    
    def build_feature_database(self, base_folder, cache_file="feature_cache.pkl"):
        """Xây dựng database đặc trưng từ thư mục ảnh"""
        # Kiểm tra cache
        if os.path.exists(cache_file):
            print("Đang tải database từ cache...")
            with open(cache_file, 'rb') as f:
                return pickle.load(f)
        
        feature_db = {}
        valid_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff')
        
        # Lấy danh sách tất cả file ảnh
        image_files = []
        for root, _, files in os.walk(base_folder):
            for file in files:
                if file.lower().endswith(valid_extensions):
                    image_files.append(os.path.join(root, file))
        
        # Trích xuất đặc trưng với progress bar
        for img_path in tqdm(image_files, desc="Trích xuất đặc trưng"):
            features = self.extract_features(img_path)
            if features is not None:
                feature_db[img_path] = features
        
        # Lưu cache
        with open(cache_file, 'wb') as f:
            pickle.dump(feature_db, f)
        
        return feature_db

# %% [markdown]
# Similarity Calculator (Tính toán độ tương đồng)

# %%
class SimilarityCalculator:
    @staticmethod
    def cosine_similarity(vec1, vec2):
        """Tính độ tương đồng cosine giữa hai vector"""
        return np.dot(vec1, vec2) / (norm(vec1) * norm(vec2))
    
    @staticmethod
    def find_duplicates(feature_db, threshold=0.9):
        """Tìm các cặp ảnh trùng lặp dựa trên ngưỡng similarity"""
        paths = list(feature_db.keys())
        features = np.array([feature_db[path] for path in paths])
        
        # Tính ma trận similarity một lần
        similarity_matrix = cosine_similarity(features)
        
        # Tìm các cặp trùng lặp
        duplicates = []
        n = len(paths)
        
        for i in range(n):
            for j in range(i+1, n):
                if similarity_matrix[i, j] >= threshold:
                    duplicates.append((paths[i], paths[j], similarity_matrix[i, j]))
        
        return duplicates

# %% [markdown]
# Results Handler (Xử lý và hiển thị kết quả)

# %%
class ResultsHandler:
    @staticmethod
    def print_results(duplicates, threshold=0.9):
        """In kết quả các cặp ảnh trùng lặp kèm label"""
        if not duplicates:
            print("Không tìm thấy ảnh trùng lặp nào.")
            return
        
        print(f"\nTìm thấy {len(duplicates)} cặp ảnh trùng lặp:")
        for img1, img2, sim in duplicates:
            label = 1 if sim >= threshold else 0
            print(f"{os.path.basename(img1)} <--> {os.path.basename(img2)} : similarity = {sim:.4f}, label = {label}")
    
    @staticmethod
    def save_results(duplicates, txt_file="duplicates.txt", excel_file="duplicates.xlsx", threshold=0.9):
        """Lưu kết quả vào file TXT và Excel"""
        if not duplicates:
            with open(txt_file, 'w', encoding='utf-8') as f:
                f.write("Không tìm thấy ảnh trùng lặp nào.")
            print(f"Không tìm thấy ảnh trùng lặp nào. Kết quả đã lưu vào {txt_file}")
            return
        
        # ---- Lưu file TXT ----
        with open(txt_file, 'w', encoding='utf-8') as f:
            f.write(f"Tìm thấy {len(duplicates)} cặp ảnh trùng lặp:\n")
            for img1, img2, sim in duplicates:
                label = 1 if sim >= threshold else 0
                f.write(f"{img1} <--> {img2} : similarity = {sim:.4f}, label = {label}\n")
        
        # ---- Lưu file Excel ----
        data = []
        for img1, img2, sim in duplicates:
            label = 1 if sim >= threshold else 0
            data.append([os.path.basename(img1), os.path.basename(img2), sim, label])
        
        df = pd.DataFrame(data, columns=["Ảnh 1", "Ảnh 2", "Similarity", "Label"])
        df.to_excel(excel_file, index=False)
        
        print(f"\nĐã lưu kết quả vào:\n- {txt_file}\n- {excel_file}")

# %% [markdown]
# Main Application

# %%
import time


def main():
    start_time = time.time()
    
    # Khởi tạo các thành phần
    extractor = FeatureExtractor()
    calculator = SimilarityCalculator()
    results_handler = ResultsHandler()
    
    # Bước 1: Trích xuất đặc trưng
    print("Bước 1: Đang trích xuất đặc trưng từ ảnh...")
    feature_db = extractor.build_feature_database("images_png")
    
    # Bước 2: Tính toán độ tương đồng
    print("Bước 2: Đang tính toán độ tương đồng...")
    duplicates = calculator.find_duplicates(feature_db, threshold=0.9)
    
    # Bước 3: Hiển thị và lưu kết quả
    print("Bước 3: Đang xử lý kết quả...")
    results_handler.print_results(duplicates)
    results_handler.save_results(duplicates)
    
    end_time = time.time()
    print(f"\nThời gian thực hiện: {end_time - start_time:.2f} giây")

# Trong notebook chỉ cần gọi main()
main()
# Out:
# Bước 1: Đang trích xuất đặc trưng từ ảnh...
# Đang tải database từ cache...
# Bước 2: Đang tính toán độ tương đồng...
# Bước 3: Đang xử lý kết quả...
#
# Tìm thấy 231 cặp ảnh trùng lặp:
# 106641569.png <--> 57071523.png : similarity = 1.0000, label = 1
# 131416196.png <--> 74500335.png : similarity = 1.0000, label = 1
# 154259057.png <--> 263588554.png : similarity = 0.9983, label = 1
# 174896487.png <--> 85764360.png : similarity = 0.9353, label = 1
# 194067352.png <--> 212934661.png : similarity = 1.0000, label = 1
# 194067352.png <--> 274879959.png : similarity = 1.0000, label = 1
# 194067352.png <--> 277381589.png : similarity = 0.9082, label = 1
# 194121937.png <--> 194130039.png : similarity = 0.9199, label = 1
# 212934661.png <--> 274879959.png : similarity = 1.0000, label = 1
# 212934661.png <--> 277381589.png : similarity = 0.9082, label = 1
# 222452404.png <--> 274069561.png : similarity = 0.9656, label = 1
# 262792654.png <--> 269944956.png : similarity = 1.0000, label = 1
# 262792654.png <--> 270977143.png : similarity = 1.0000, label = 1
# 262792654.png <--> 270977170.png : similarity = 1.0000, label = 1
# 263987622.png <--> 275773160.png : similarity = 0.9975, label = 1
# 263987622.png <--> 47868431.png : similarity = 1.0000, label = 1
# 269944956.png <--> 270977143.png : similarity = 1.0000, label = 1
# 269944956.png <--> 270977170.png : similarity = 1.0000, label = 1
# 270977143.png <--> 270977170.png : similarity = 1.0000, label = 1
# 274184765.png <--> 277381589.png : similarity = 0.9155, label = 1
# 274879959.png <--> 277381589.png : similarity = 0.9082, label = 1
# 275773160.png <--> 47868431.png : similarity = 0.9975, label = 1
# 198437064.png <--> 225934432.png : similarity = 0.9432, label = 1
# 198437064.png <--> 225940640.png : similarity = 0.9432, label = 1
# 205305968.png <--> 273239856.png : similarity = 1.0000, label = 1
# 205305968.png <--> 274775419.png : similarity = 0.9506, label = 1
# 205305968.png <--> 278454662.png : similarity = 1.0000, label = 1
# 214863343.png <--> 214863390.png : similarity = 0.9987, label = 1
# 225363237.png <--> 92621126.png : similarity = 0.9564, label = 1
# 225934432.png <--> 225940640.png : similarity = 1.0000, label = 1
# 252566338.png <--> 276365829.png : similarity = 0.9432, label = 1
# 252566338.png <--> 276366073.png : similarity = 0.9034, label = 1
# 252566338.png <--> 278076593.png : similarity = 0.9792, label = 1
# 252566338.png <--> 278078281.png : similarity = 0.9728, label = 1
# 252566338.png <--> 278078315.png : similarity = 0.9793, label = 1
# 272828266.png <--> 274419342.png : similarity = 0.9046, label = 1
# 273239856.png <--> 274775419.png : similarity = 0.9506, label = 1
# 273239856.png <--> 278454662.png : similarity = 1.0000, label = 1
# 273634022.png <--> 273647623.png : similarity = 0.9770, label = 1
# 273634022.png <--> 275516477.png : similarity = 0.9102, label = 1
# 273634022.png <--> 275852844.png : similarity = 0.9566, label = 1
# 273647623.png <--> 275852844.png : similarity = 0.9516, label = 1
# 274419342.png <--> 275381290.png : similarity = 0.9265, label = 1
# 274419342.png <--> 275382480.png : similarity = 0.9080, label = 1
# 274419342.png <--> 275382529.png : similarity = 0.9157, label = 1
# 274419342.png <--> 275850110.png : similarity = 0.9157, label = 1
# 274775419.png <--> 278454662.png : similarity = 0.9506, label = 1
# 275381290.png <--> 275382529.png : similarity = 0.9101, label = 1
# 275382480.png <--> 275382529.png : similarity = 0.9009, label = 1
# 275382480.png <--> 275850110.png : similarity = 0.9506, label = 1
# 275382529.png <--> 275850110.png : similarity = 0.9120, label = 1
# 275516477.png <--> 275850110.png : similarity = 0.9107, label = 1
# 275516477.png <--> 275852844.png : similarity = 0.9014, label = 1
# 275721993.png <--> 275854376.png : similarity = 0.9606, label = 1
# 275721993.png <--> 275854386.png : similarity = 0.9607, label = 1
# 275850110.png <--> 275852844.png : similarity = 0.9010, label = 1
# 275854376.png <--> 275854386.png : similarity = 0.9997, label = 1
# 276365829.png <--> 278076593.png : similarity = 0.9481, label = 1
# 276365829.png <--> 278078281.png : similarity = 0.9418, label = 1
# 276365829.png <--> 278078315.png : similarity = 0.9481, label = 1
# 276366073.png <--> 278076593.png : similarity = 0.9093, label = 1
# 276366073.png <--> 278078281.png : similarity = 0.9084, label = 1
# 276366073.png <--> 278078315.png : similarity = 0.9095, label = 1
# 276366080.png <--> 277451016.png : similarity = 0.9010, label = 1
# 276366080.png <--> 278078298.png : similarity = 0.9163, label = 1
# 276366080.png <--> 278078311.png : similarity = 0.9192, label = 1
# 276366221.png <--> 276366329.png : similarity = 0.9779, label = 1
# 277361271.png <--> 277672516.png : similarity = 0.9480, label = 1
# 277361314.png <--> 277446629.png : similarity = 0.9121, label = 1
# 277446629.png <--> 277912853.png : similarity = 0.9686, label = 1
# 277446629.png <--> 278071899.png : similarity = 0.9318, label = 1
# 277451016.png <--> 278078298.png : similarity = 0.9168, label = 1
# 277451016.png <--> 278078311.png : similarity = 0.9024, label = 1
# 277462473.png <--> 277912715.png : similarity = 0.9046, label = 1
# 277462473.png <--> 277912717.png : similarity = 0.9077, label = 1
# 277462473.png <--> 277912740.png : similarity = 0.9041, label = 1
# 277672516.png <--> 277912853.png : similarity = 0.9026, label = 1
# 277912715.png <--> 277912717.png : similarity = 0.9993, label = 1
# 277912853.png <--> 278071899.png : similarity = 0.9196, label = 1
# 278076593.png <--> 278078281.png : similarity = 0.9788, label = 1
# 278076593.png <--> 278078315.png : similarity = 0.9998, label = 1
# 278078281.png <--> 278078315.png : similarity = 0.9788, label = 1
# 278078298.png <--> 278078311.png : similarity = 0.9366, label = 1
# 278226504.png <--> 278226626.png : similarity = 0.9751, label = 1
# 278226504.png <--> 278226869.png : similarity = 0.9671, label = 1
# 278226504.png <--> 278227010.png : similarity = 0.9741, label = 1
# 278226504.png <--> 278229740.png : similarity = 0.9372, label = 1
# 278226504.png <--> 278304303.png : similarity = 0.9544, label = 1
# 278226504.png <--> 278304363.png : similarity = 0.9593, label = 1
# 278226504.png <--> 278304793.png : similarity = 0.9514, label = 1
# 278226626.png <--> 278226869.png : similarity = 0.9539, label = 1
# 278226626.png <--> 278227010.png : similarity = 0.9598, label = 1
# 278226626.png <--> 278229740.png : similarity = 0.9340, label = 1
# 278226626.png <--> 278304303.png : similarity = 0.9628, label = 1
# 278226626.png <--> 278304363.png : similarity = 0.9685, label = 1
# 278226626.png <--> 278304793.png : similarity = 0.9682, label = 1
# 278226869.png <--> 278227010.png : similarity = 0.9531, label = 1
# 278226869.png <--> 278229740.png : similarity = 0.9054, label = 1
# 278226869.png <--> 278304303.png : similarity = 0.9285, label = 1
# 278226869.png <--> 278304363.png : similarity = 0.9303, label = 1
# 278226869.png <--> 278304793.png : similarity = 0.9289, label = 1
# 278227010.png <--> 278229740.png : similarity = 0.9470, label = 1
# 278227010.png <--> 278304303.png : similarity = 0.9724, label = 1
# 278227010.png <--> 278304363.png : similarity = 0.9771, label = 1
# 278227010.png <--> 278304793.png : similarity = 0.9667, label = 1
# 278229740.png <--> 278304303.png : similarity = 0.9457, label = 1
# 278229740.png <--> 278304363.png : similarity = 0.9460, label = 1
# 278229740.png <--> 278304793.png : similarity = 0.9393, label = 1
# 278304303.png <--> 278304363.png : similarity = 0.9824, label = 1
# 278304303.png <--> 278304793.png : similarity = 0.9852, label = 1
# 278304363.png <--> 278304793.png : similarity = 0.9821, label = 1
# 11251770.png <--> 181927774.png : similarity = 0.9751, label = 1
# 184059211.png <--> 197214029.png : similarity = 0.9315, label = 1
# 201067649.png <--> 252586291.png : similarity = 0.9093, label = 1
# 270975124.png <--> 271128271.png : similarity = 0.9560, label = 1
# 273990229.png <--> 276274790.png : similarity = 0.9213, label = 1
# 273990229.png <--> 276944892.png : similarity = 0.9237, label = 1
# 274405521.png <--> 276274790.png : similarity = 0.9142, label = 1
# 274405521.png <--> 276944892.png : similarity = 0.9144, label = 1
# 276062770.png <--> 277311630.png : similarity = 0.9997, label = 1
# 276062770.png <--> 277737629.png : similarity = 0.9215, label = 1
# 276109904.png <--> 276110023.png : similarity = 0.9702, label = 1
# 276110276.png <--> 276110349.png : similarity = 0.9767, label = 1
# 276274790.png <--> 276944892.png : similarity = 0.9989, label = 1
# 276274790.png <--> 277737629.png : similarity = 0.9025, label = 1
# 276281988.png <--> 276925932.png : similarity = 0.9264, label = 1
# 276281988.png <--> 277646748.png : similarity = 0.9529, label = 1
# 276281988.png <--> 277651890.png : similarity = 0.9607, label = 1
# 276448920.png <--> 276539826.png : similarity = 0.9408, label = 1
# 276639232.png <--> 276944868.png : similarity = 0.9569, label = 1
# 276639232.png <--> 277704510.png : similarity = 0.9148, label = 1
# 276639232.png <--> 277737595.png : similarity = 0.9521, label = 1
# 276639232.png <--> 277944334.png : similarity = 0.9537, label = 1
# 276802409.png <--> 276925932.png : similarity = 0.9543, label = 1
# 276802409.png <--> 277646748.png : similarity = 0.9246, label = 1
# 276802409.png <--> 277651890.png : similarity = 0.9251, label = 1
# 276925932.png <--> 277646748.png : similarity = 0.9209, label = 1
# 276925932.png <--> 277651890.png : similarity = 0.9184, label = 1
# 276944868.png <--> 277512611.png : similarity = 0.9056, label = 1
# 276944868.png <--> 277512620.png : similarity = 0.9141, label = 1
# 276944868.png <--> 277704510.png : similarity = 0.9489, label = 1
# 276944868.png <--> 277737595.png : similarity = 0.9572, label = 1
# 276944868.png <--> 277944334.png : similarity = 0.9579, label = 1
# 276944892.png <--> 277737629.png : similarity = 0.9081, label = 1
# 277063012.png <--> 277065642.png : similarity = 1.0000, label = 1
# 277175913.png <--> 277811118.png : similarity = 0.9742, label = 1
# 277311630.png <--> 277737629.png : similarity = 0.9211, label = 1
# 277360579.png <--> 277737629.png : similarity = 0.9604, label = 1
# 277512611.png <--> 277512620.png : similarity = 0.9270, label = 1
# 277512620.png <--> 277704510.png : similarity = 0.9082, label = 1
# 277646748.png <--> 277651890.png : similarity = 0.9954, label = 1
# 277704510.png <--> 277737595.png : similarity = 0.9464, label = 1
# 277704510.png <--> 277944334.png : similarity = 0.9467, label = 1
# 277707642.png <--> 277777809.png : similarity = 0.9285, label = 1
# 277737595.png <--> 277944334.png : similarity = 0.9991, label = 1
# 21430781.png <--> 73204703.png : similarity = 0.9184, label = 1
# 241635069.png <--> 241638318.png : similarity = 0.9668, label = 1
# 241635069.png <--> 241639907.png : similarity = 0.9565, label = 1
# 241638318.png <--> 241639907.png : similarity = 0.9643, label = 1
# 276075423.png <--> 276075466.png : similarity = 0.9520, label = 1
# 57523356.png <--> 76062253.png : similarity = 0.9478, label = 1
# 207872108.png <--> 248237801.png : similarity = 0.9497, label = 1
# 274843293.png <--> 274843323.png : similarity = 0.9891, label = 1
# 274843293.png <--> 274843351.png : similarity = 0.9774, label = 1
# 274843293.png <--> 274870404.png : similarity = 0.9336, label = 1
# 274843293.png <--> 274870762.png : similarity = 0.9154, label = 1
# 274843293.png <--> 274876803.png : similarity = 0.9349, label = 1
# 274843293.png <--> 274877090.png : similarity = 0.9213, label = 1
# 274843293.png <--> 275655333.png : similarity = 0.9994, label = 1
# 274843323.png <--> 274843351.png : similarity = 0.9773, label = 1
# 274843323.png <--> 274870404.png : similarity = 0.9405, label = 1
# 274843323.png <--> 274870762.png : similarity = 0.9140, label = 1
# 274843323.png <--> 274876803.png : similarity = 0.9385, label = 1
# 274843323.png <--> 274877090.png : similarity = 0.9266, label = 1
# 274843323.png <--> 275646608.png : similarity = 0.9006, label = 1
# 274843323.png <--> 275655333.png : similarity = 0.9888, label = 1
# 274843351.png <--> 274870404.png : similarity = 0.9303, label = 1
# 274843351.png <--> 274870762.png : similarity = 0.9160, label = 1
# 274843351.png <--> 274876803.png : similarity = 0.9298, label = 1
# 274843351.png <--> 274877090.png : similarity = 0.9187, label = 1
# 274843351.png <--> 275655333.png : similarity = 0.9771, label = 1
# 274870404.png <--> 274870762.png : similarity = 0.9398, label = 1
# 274870404.png <--> 274876803.png : similarity = 0.9699, label = 1
# 274870404.png <--> 274877090.png : similarity = 0.9633, label = 1
# 274870404.png <--> 275655333.png : similarity = 0.9342, label = 1
# 274870710.png <--> 276268195.png : similarity = 0.9040, label = 1
# 274870762.png <--> 274876803.png : similarity = 0.9598, label = 1
# 274870762.png <--> 274877090.png : similarity = 0.9603, label = 1
# 274870762.png <--> 275655333.png : similarity = 0.9157, label = 1
# 274876803.png <--> 274877090.png : similarity = 0.9795, label = 1
# 274876803.png <--> 275646608.png : similarity = 0.9024, label = 1
# 274876803.png <--> 275655333.png : similarity = 0.9360, label = 1
# 274877090.png <--> 275655333.png : similarity = 0.9217, label = 1
# 275019168.png <--> 275020293.png : similarity = 1.0000, label = 1
# 275019168.png <--> 275020992.png : similarity = 0.9869, label = 1
# 275020293.png <--> 275020992.png : similarity = 0.9869, label = 1
# 275244561.png <--> 275244939.png : similarity = 0.9987, label = 1
# 275244561.png <--> 276621654.png : similarity = 0.9327, label = 1
# 275244939.png <--> 276621654.png : similarity = 0.9331, label = 1
# 275245427.png <--> 275249046.png : similarity = 0.9948, label = 1
# 275245427.png <--> 275249107.png : similarity = 0.9958, label = 1
# 275245427.png <--> 275803796.png : similarity = 0.9977, label = 1
# 275245427.png <--> 275805126.png : similarity = 0.9904, label = 1
# 275249046.png <--> 275249107.png : similarity = 0.9935, label = 1
# 275249046.png <--> 275803796.png : similarity = 0.9949, label = 1
# 275249046.png <--> 275805126.png : similarity = 0.9862, label = 1
# 275249107.png <--> 275803796.png : similarity = 0.9953, label = 1
# 275249107.png <--> 275805126.png : similarity = 0.9900, label = 1
# 275269812.png <--> 275270303.png : similarity = 0.9940, label = 1
# 275269812.png <--> 275603123.png : similarity = 0.9951, label = 1
# 275269812.png <--> 275603494.png : similarity = 0.9932, label = 1
# 275269812.png <--> 275655645.png : similarity = 0.9940, label = 1
# 275270303.png <--> 275603123.png : similarity = 0.9983, label = 1
# 275270303.png <--> 275603494.png : similarity = 0.9997, label = 1
# 275270303.png <--> 275655645.png : similarity = 1.0000, label = 1
# 275603123.png <--> 275603494.png : similarity = 0.9979, label = 1
# 275603123.png <--> 275655645.png : similarity = 0.9983, label = 1
# 275603494.png <--> 275655645.png : similarity = 0.9997, label = 1
# 275803796.png <--> 275805126.png : similarity = 0.9895, label = 1
# 276032905.png <--> 276921311.png : similarity = 0.9967, label = 1
# 276319244.png <--> 276362981.png : similarity = 0.9560, label = 1
# 276860956.png <--> 276931435.png : similarity = 0.9990, label = 1
# 276861471.png <--> 276861683.png : similarity = 0.9968, label = 1
# 277429931.png <--> 277991140.png : similarity = 0.9071, label = 1
# 277575237.png <--> 277575279.png : similarity = 0.9993, label = 1
# 277971781.png <--> 277971948.png : similarity = 0.9687, label = 1
# 277972387.png <--> 277972475.png : similarity = 0.9832, label = 1
# 277976029.png <--> 277989480.png : similarity = 0.9672, label = 1
# 277988890.png <--> 277988926.png : similarity = 0.9897, label = 1
# 278077327.png <--> 278077419.png : similarity = 0.9345, label = 1
# 278138206.png <--> 278138258.png : similarity = 0.9855, label = 1
#
# Đã lưu kết quả vào:
# - duplicates.txt
# - duplicates.xlsx
#
# Thời gian thực hiện: 1.19 giây
